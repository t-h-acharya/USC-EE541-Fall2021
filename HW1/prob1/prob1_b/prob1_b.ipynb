# %% [markdown]
# ## Homework #1 – Tools and Fundamentals
# ### Problem 1(b)
# ### Name: Tejas Harishchandra Acharya
# ### Date: 08/08/2025

# %%
# Imports
import random
import matplotlib.pyplot as plt

# %%
# Constants
P_HEAD = 0.7

# %%
def is_head():
    return random.uniform(0, 1) < P_HEAD

# %%
def get_trials(num_trials):
    return [is_head() for i in range(num_trials)]

# %%
def get_longest_run_heads(trials):
    max_run = 0
    curr_run = 1 if trials[0] else 0

    for i in range(1, len(trials)):
        if trials[i]:
            if trials[i] == trials[i - 1]:
                curr_run += 1
            else:
                curr_run = 1
        else:
            max_run = max(max_run, curr_run)
            curr_run = 0
    return max_run

# %%
num_trials = 500

# %%
num_repeats = 20

longest_heads_run_list = [get_longest_run_heads(get_trials(num_trials)) for i in range(num_repeats)]

plt.figure()
plt.hist(longest_heads_run_list)
plt.xlabel("Longest Run of Heads")
plt.ylabel("Count")
plt.title(f"Histogram of Longest Run of Heads for {num_repeats} repeats of flipping the coin {num_trials} times")
plt.show()

# %%
num_repeats = 100

longest_heads_run_list = [get_longest_run_heads(get_trials(num_trials)) for i in range(num_repeats)]

plt.figure()
plt.hist(longest_heads_run_list)
plt.xlabel("Longest Run of Heads")
plt.ylabel("Count")
plt.title(f"Histogram of Longest Run of Heads for {num_repeats} repeats of flipping the coin {num_trials} times")
plt.show()

# %%
num_repeats = 200

longest_heads_run_list = [get_longest_run_heads(get_trials(num_trials)) for i in range(num_repeats)]

plt.figure()
plt.hist(longest_heads_run_list)
plt.xlabel("Longest Run of Heads")
plt.ylabel("Count")
plt.title(f"Histogram of Longest Run of Heads for {num_repeats} repeats of flipping the coin {num_trials} times")
plt.show()

# %%
num_repeats = 1000

longest_heads_run_list = [get_longest_run_heads(get_trials(num_trials)) for i in range(num_repeats)]

plt.figure()
plt.hist(longest_heads_run_list)
plt.xlabel("Longest Run of Heads")
plt.ylabel("Count")
plt.title(f"Histogram of Longest Run of Heads for {num_repeats} repeats of flipping the coin {num_trials} times")
plt.show()
